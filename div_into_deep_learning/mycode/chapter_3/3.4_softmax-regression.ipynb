# %%
import sys
sys.path.append("../")
from d2l import torch as d2l
# %matplotlib inline
import random
import torch
import numpy as np
from torch.utils import data

# %% [markdown]
# ### 独热编码（one-hot encoding）。
#
# 独热编码是一个向量，它的分量和类别一样多。 类别对应的分量设置为1，其他所有分量设置为0。 在我们的例子中，标签
# 将是一个三维向量， 其中
# 对应于“猫”、
# 对应于“鸡”、
# 对应于“狗”：
#
# $y \in \{(1, 0, 0), (0, 1, 0), (0, 0, 1)\}.$
#
# ### 仿射变换
#
# 是线性变换 + 平移​ 的组合，可表示为：
